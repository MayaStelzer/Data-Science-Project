# %% [markdown]
# # Maura and Maya Project Proposal: Mushroom Classification

# %% [markdown]
# ## Dataset Description
# This dataset can be used to classify a mushroom as edible or poisonous based on the cap shape, cap surface texture, cap color, the existence of bruises, odor, if and how the gill is attachment, the gills' spacing, gill size, gill color, stalk shape, stalk root, the texture of the stalk surface above and below the ring, stalk color above and below the ring, the veil type, veil color, the number of rings, type of ring(s), spore print color, the size and distribution of the population, and the habitat
# Sourced from Kaggle: https://www.kaggle.com/datasets/uciml/mushroom-classification?select=mushrooms.csv
#
# TODO: dataset format and contents

# %% [markdown]
# ## Implementation/technical merit
# TODO: Anticipated challenges in pre-processing and/or classification (e.g., missing values, class distribution, etc.)
# TODO: If the number of attributes is large, how will you explore feature selection techniques to pare down the attributes?

# %% [markdown]
# ## Potential impact of the results
# TODO: Why are these results useful?
# TODO: Who are stakeholders (users/groups that are impacted by the outcome of the project) interested in these results?

# %% [markdown]
# Citations for data, code, and/or materials you plan to use that are outside the scope of what was provided in this course (this includes previous course projects).
